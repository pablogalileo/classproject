# %% [markdown]
# Laboratorio #2

# %%
# !pip install mlflow
# Out:
# ...
# ERROR: Operation cancelled by user

# %%
from pycaret.datasets import get_data
import pandas as pd
from pycaret.regression import *

# %%
all_datasets = get_data('index')
#Para checar los nombres de los datasets disponibles,
#Se encontro el dataset 'house' que es el de house prices de kaggle
data_house = get_data(dataset='house')
# Out:
#                              Dataset    Data Types  \
# 0                            anomaly  Multivariate
# 1                             france  Multivariate
# 2                            germany  Multivariate
# 3                               bank  Multivariate
# 4                              blood  Multivariate
# 5                             cancer  Multivariate
# 6                             credit  Multivariate
# 7                           diabetes  Multivariate
# 8                    electrical_grid  Multivariate
# 9                           employee  Multivariate
# 10                             heart  Multivariate
# 11                     heart_disease  Multivariate
# 12                         hepatitis  Multivariate
# 13                            income  Multivariate
# 14                             juice  Multivariate
# 15                               nba  Multivariate
# 16                              wine  Multivariate
# ...

# %% [markdown]
# EDA y profiling

# %%
data_house = get_data(dataset='house', profile=True)
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# Warnings

# %% [markdown]
# Las variables que tienen warnings de muchos datos faltantes son: 'Alley', 'PoolQC', 'MiscFeature', 'Fence', 'FireplaceQu', 'Utilities'
#
# Estas se eliminarán del dataset
#
# La imputación de datos será por medio de eliminación ya que no hay porcentajes muy altos
#
# Hay peligro de multicolinealidad por lo que se activará remove_multicollinearity

# %%
num_filas_train = int(len(data_house)*0.8)

data_train = data_house.sample(n=num_filas_train, random_state=2023)
data_test = data_house.drop(data_train.index)

# %%
print(f"Filas en Train: {data_train.shape[0]}")
print(f"Filas en Test: {data_test.shape[0]}")

# %% [markdown]
# Setup del modelo

# %%
dataset = setup(data = data_train,
                target = 'SalePrice',
                session_id=2023,
                normalize=True,
                normalize_method='minmax',
                transformation=True,
                transformation_method = 'yeo-johnson',
                transform_target = True,
                ignore_features = ['Alley','PoolQC','MiscFeature','Fence','FireplaceQu','Utilities'],
                remove_outliers= True,
                log_experiment=True,
                remove_multicollinearity = True,
                experiment_name='Sale Price predict'
                )
# Out:
# <style type="text/css">
# #T_bacb5_row12_col1, #T_bacb5_row18_col1, #T_bacb5_row20_col1, #T_bacb5_row22_col1, #T_bacb5_row24_col1, #T_bacb5_row26_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_bacb5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bacb5_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_bacb5_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bacb5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bacb5_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_bacb5_row0_col1" class="data row0 col1" >2023</td>
#     </tr>
#     <tr>
#       <th id="T_bacb5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bacb5_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_bacb5_row1_col1" class="data row1 col1" >SalePrice</td>
# ...

# %% [markdown]
# Entrenamiento y seleccion de modelos

# %%
best = compare_models(sort='RMSE')
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .           05:48:16
# Status     . . . . . . . . . . . . . . . . . .   Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Linear Regression
# Empty DataFrame
# Columns: [Model, MAE, MSE, RMSE, R2, RMSLE, MAPE, TT (Sec)]
# Index: []
# Processing:   0%|          | 0/81 [00:00<?, ?it/s]

# %%
print(best)

# %%
tuned_best=tune_model(estimator=best)

# %% [markdown]
# Eleccion de modelo

# %%
final_model = finalize_model(estimator=best)

# %% [markdown]
# Almacenamiento de pipeline en disco duro

# %%
save_model(model=final_model,model_name='C:\Users\pablo\Documents\2 ESTUDIO\1 MAESTRÍA BI & Analytics - Galileo\2 Postgrado Analytics\4 Cuarto Trimestre\1 Product Development\TAREAS\Lab2\model_v1')

# %% [markdown]
# Predicciones
